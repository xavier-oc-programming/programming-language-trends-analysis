# %% [markdown]
# Here is the **study note rewritten and adapted for VS Code**, keeping your Day 73 structure and your XaviNote tone.
# This corresponds to **1)—Download and Open the Starter Notebook**, but adjusted away from Colab/Google Drive and into a **local VS Code + Jupyter workflow**.
#
# ---
#
# ## **1)—Download and Open the Starter Notebook (VS Code Version)**
#
# ### **Objective**
#
# Set up the starter notebook and dataset locally so you can work entirely inside **VS Code** using a Jupyter Notebook.
#
# ---
#
# ### **Open the Template (VS Code Workflow)**
#
# To help you get started with this data exploration project, a **starter notebook** is provided.
# This notebook already contains the main sections and challenges for the lesson.
#
# **Steps:**
#
# 1. Download the `.zip` file from the lesson resources:
#
#    * `Programming_Languages_(start).ipynb.zip`
#
# 2. Unzip the file locally.
#
# 3. Move the extracted folder into your **Day 73 project directory**.
#
# 4. Open the folder in **VS Code**:
#
#    * `File → Open Folder`
#    * Select the Day 73 folder
#
# 5. Open the notebook file:
#
#    * `Programming_Languages_(start).ipynb`
#
# Make sure:
#
# * The **Python extension** is installed
# * The **Jupyter extension** is installed
# * The correct **Python environment / kernel** is selected (top-right of the notebook)
#
# ---
#
# ### **Import the Data**
#
# The lesson includes a CSV file containing **Stack Overflow post data**.
#
# **File provided:**
#
# * `QueryResults.csv`
#
# **Steps:**
#
# 1. Download `QueryResults.csv` from the lesson resources.
# 2. Place it in the **same folder** as the notebook (recommended).
# 3. Confirm VS Code shows the file in the Explorer panel.
#
# Keeping the CSV in the same directory avoids path issues when loading data with Pandas.
#
# ---
#
# ### **Challenge: Initial Data Exploration**
#
# Recreate the exploration steps from the previous lesson using Pandas.
#
# #### **Tasks**
#
# * Read the CSV file into a Pandas DataFrame called `df`
# * Explicitly assign the column names:
#
#   ```
#   ['DATE', 'TAG', 'POSTS']
#   ```
# * Inspect the **first 5 rows**
# * Inspect the **last 5 rows**
# * Determine:
#
#   * Number of rows
#   * Number of columns
# * Count the number of non-null entries in each column
#
# This step ensures:
#
# * The data loaded correctly
# * Column names are clean and consistent
# * You understand the dataset structure before analysis and visualisation
#
# ---
#
# ### **Why This Matters**
#
# Before creating any plots or trends:
#
# * You must confirm the data is structured correctly
# * Time-based analysis depends on clean timestamps
# * Aggregation and pivoting require consistent columns
#
# Skipping this step leads to incorrect conclusions later.
#
# ---
#
# ### **End Result**
#
# By the end of this step, you will have:
#
# * A fully working **local Jupyter notebook in VS Code**
# * The Stack Overflow dataset loaded into Pandas
# * A verified and understood dataset ready for manipulation and visualisation
#
# ---
#
# When you are ready, next we can continue with:
#
# **2)—Solution: Preliminary Data Exploration**
# or convert this directly into a **ready-to-paste Jupyter Notebook cell layout** following your exact XaviNote format.
